# %% [markdown]
# <a href="https://colab.research.google.com/github/itsayushiii/Decison-Tree/blob/main/decision_tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
#import seaborn as sb  #data visualization
import warnings
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
warnings.filterwarnings("ignore")

df = pd.DataFrame(
    {
        "Age" : [17,64,18,20,38,49,55,25,29,31,33],
        "Salary": [25,80,22,36,37,59,74,70,33,102,88],
        "Loan Default": [1,0,1,0,1,0,0,0,1,1,0]
    }
)

# %%
df

# %%
features = ['Age','Salary']

x=df[features]
y = df['Loan Default']
dtree = DecisionTreeClassifier( criterion="entropy",max_depth=5)
dtree = dtree.fit(x,y)
tree.plot_tree(dtree, feature_names=features)
# Out:
# [Text(0.5, 0.9, 'Salary <= 34.5\nentropy = 0.994\nsamples = 11\nvalue = [6, 5]'),
#  Text(0.3333333333333333, 0.7, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6666666666666666, 0.7, 'Salary <= 95.0\nentropy = 0.811\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.5, 0.5, 'Salary <= 48.0\nentropy = 0.592\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.3333333333333333, 0.3, 'Salary <= 36.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.16666666666666666, 0.1, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5, 0.1, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6666666666666666, 0.3, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.8333333333333334, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]')]
